# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
import seaborn as sns
from statsmodels.compat import lzip
import statsmodels.stats.api as sms
from scipy.stats import shapiro

# %%
data = pd.read_excel("raciones2.xlsx")

# %%
data.head()
# Out:
#     Rbd  Enero  Febrero  Marzo  Abril   Mayo  Junio  Julio  Agosto
# 0  2102      0        0  22761  24732  24307  23270  13673   24307  \
# 1  2103      0        0  23951  24921  21848  21024  12908   21633
# 2  2104      0        0  32349  35693  35835  34242  19851   35919
# 3  2105      0        0  16095  17765  17298  16488   9519   17361
# 4  2109      0        0  17315  18504  17833  17156  10301   17833
#
#    Septiembre  ...    Junio$    Julio$   Agosto$  Septiembre$  Octubre$
# 0       21567  ...  14194224  28388448  14194224     28685391  14342695  \
# 1       19259  ...  14593258  28331443  14165721     14313895  28627790
# 2       37200  ...  20008725  40017450  20008725     20218016  40436033
# 3       14922  ...   8208707  16417415   8208707      8294570  16589141
# 4       16035  ...  12313061  24626123  12313061     24883712  12441856
#
#    Noviembre$  Diciembre$     Total$  Promedio mensual$
# 0    14342695    14540624  177480877       1.479007e+07  \
# 1    14313895    14511426  178132122       1.484434e+07
# 2    20218016    20497025  249813102       2.081776e+07
# 3     8294570     8409036  103133991       8.594499e+06
# 4    12441856    12613554  151814466       1.265121e+07
#
#    Promedio mensual efectivo$
# 0                  17748087.7
# 1                  17813212.2
# 2                  24981310.2
# 3                  10313399.1
# 4                  15181446.6
#
# [5 rows x 31 columns]

# %%
data.rename(columns={'Total$': 'Total_precio'}).head(1)
# Out:
#     Rbd  Enero  Febrero  Marzo  Abril   Mayo  Junio  Julio  Agosto
# 0  2102      0        0  22761  24732  24307  23270  13673   24307  \
#
#    Septiembre  ...    Junio$    Julio$   Agosto$  Septiembre$  Octubre$
# 0       21567  ...  14194224  28388448  14194224     28685391  14342695  \
#
#    Noviembre$  Diciembre$  Total_precio  Promedio mensual$
# 0    14342695    14540624     177480877       1.479007e+07  \
#
#    Promedio mensual efectivo$
# 0                  17748087.7
#
# [1 rows x 31 columns]

# %%
data['precio_racion'] = data['Total$']/data['Total']
data = data[data['precio_racion'] < 10000]

# %%
plt.scatter(data['Total'], data['precio_racion'], color='purple', s=15, alpha=0.2)
plt.xlabel('Número de raciones')
plt.ylabel('Precio por ración')
plt.grid(True)
plt.title('Promedio anual de consolidado2020')
# Out:
# Text(0.5, 1.0, 'Promedio anual de consolidado2020')

# %%
model = smf.ols('precio_racion ~ Total', data=data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          precio_racion   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.516
# Date:                Thu, 12 Oct 2023   Prob (F-statistic):             0.0336
# Time:                        21:27:12   Log-Likelihood:                -65672.
# No. Observations:                8935   AIC:                         1.313e+05
# Df Residuals:                    8933   BIC:                         1.314e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    826.6345      5.483    150.764      0.000     815.887     837.382
# Total          0.0001   4.98e-05      2.125      0.034    8.21e-06       0.000
# ==============================================================================
# Omnibus:                     7917.567   Durbin-Watson:                   1.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           597700.033
# Skew:                           3.918   Prob(JB):                         0.00
# Kurtosis:                      42.295   Cond. No.                     1.52e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Test de homocedasticidad

names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
 
test_result = sms.het_breuschpagan(model.resid, model.model.exog)
 
lzip(names, test_result)
# Out:
# [('Lagrange multiplier statistic', 128.18206784449805),
#  ('p-value', 1.0240463543311532e-29),
#  ('f-value', 130.01863111920215),
#  ('f p-value', 6.532677451965254e-30)]
