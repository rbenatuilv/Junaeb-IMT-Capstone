# %%
import pandas as pd
import os

# %%
data_file = 'Colegios2020(UTs).xlsx'

df = pd.read_excel(data_file)

# %%
df
# Out:
#       indice     RBD  UTE  Region  \
# 0          0    2419    3       6
# 1          1   11287    3       6
# 2          2  887864    2       6
# 3          3    8325    4      10
# 4          4  887991    4       7
# ...      ...     ...  ...     ...
# 8929    8935  913163   13      13
# 8930    8936  913225   13      13
# 8931    8937  940401   12      13
# 8932    8938  941450   17      13
# 8933    8939  950254    1      12
#
#                                                  Nombre  \
# 0     COLEGIO JULIO SILVA LAZO                      ...
# 1     LICEO BERTA ZAMORANO LIZANA                   ...
# 2     TTVV ASOCIACION GUIAS Y SCOUT CHILE           ...
# 3     ESCUELA ANTUPIREN                             ...
# 4     MIL NINOS MIL SONRISAS                        ...
# ...                                                 ...
# 8929  OFICINA DE LA INFANCIA                        ...
# 8930  SUB EDUCACION PARVULARIA                      ...
# ...
